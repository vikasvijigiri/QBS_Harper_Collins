# %%
import os
import openai
import src
import combine

# %%
topics = """
Chapter 4: Force and Laws of Motion.
1. Banking of roads (only theory).
2. Conservation of momentum.
"""

# %%
guidelines = """
    1. You must not give too many sections or sub-sections, you should be extremely very detailed (give very detailed understanding of any term or concept before introduction, now matter how trivial it might be) in your explanation like a smooth flow of concepts and like a story-telling oriented.
    2. You must give age-appropriate explanation of every term, every concept, everything including the terms involved in the formulas. Also, every explanation of a concept should be followed by an example or two, you can take that from your previous responses of introduction and objectives.
    3. You must give a "Did you know?" (an interesting age-appropriate fact/curious thing of the topic as paragraph) in a nice box.      
    4. You must not give too many sections or sub-sections.
    5. You must give the output strictly in 'error-free & properly compilable' LATEX format only, you can use beautiful colors, bold fonts, and proper spacings wherever needed.
    6. You must make sure that the entire Theoretical concept part should be like smooth flow with smooth transition from one concept to another. 
    7. You must make sure that instead of giving straight away definition of a term, give a very detailed explanation or introduction, so that It makes the reader curious and interesting, you can include lengthy paragraphs.
    8. Do not Summarize at the end nor give anything extra, just focus on quality content creation of concepts. 
    9. Make minimum 13 pages of content.
    10. Most importantly, you must detailedly describe a prior concept required to know before the current concepts. 
"""

template = """
    1. Start with a scenarios and detailedly explain the concepts involved in it and connect to the topic. 
    2. Introduce detailedly with an example context you have already provided in the introduction part and slowly connect it to the core concepts of the chapter in a clear, concise manner.
    3. Include a paragraph of "Did you know?" section in a nice box/table. Here you will say the curious fact of the topic in a real-world.
    3. Explain detailedly using the context to slowly get into the principles, laws, and theories, including necessary definitions.
    4. Explain detailedly mathematical derivations or content in equation format, to help explain the concepts followed by an example.
"""

# %%
system_message = """
    You are an expert educator in physics and also a quality content generator for publishing a physics textbook of class 9. 
    Your goal is to create a very detailed "Theoretical Concept" part of a topic of a chapter for class 9 physics textbook (US).
    Your should keep in mind through the chapter that you should only generate age-appropriate and class-appropriate content strictly. It should not be beyond class 9 level.
"""

# Example usage:
file_path = "./fdocs/intro.docx"  # Replace with your DOCX file path
presponse = src.read_docx(file_path)
file_path = "./fdocs/objectives.docx"  # Replace with your DOCX file path
presponse += src.read_docx(file_path)


# file_path = "./fdocs/theoretical_concepts_1.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)
# file_path = "./fdocs/theoretical_concepts_2.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)
# file_path = "./fdocs/theoretical_concepts_3.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)

# file_path = "./fdocs/theoretical_concepts_4.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)

# file_path = "./fdocs/theoretical_concepts_5.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)

# file_path = "./fdocs/theoretical_concepts_6.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)
user_message = f"""
    You already gave me content for introduction and objectives as:

    {presponse}.

    --------------------------------------------------------



    --------------------------------------------------------
    Here, you should generate content only for the part,

    "
    Force
    1. Real life ecamples
    2. Force as vector
    3. Magnitude and direction
    4. Force examples, and types
    5. Some non-repetitive Solved step-by-step examples
    6. Do not include more headings. Include paragraphs like more story-telling type
    "    
    --------------------------------------------------------
    Template you can follow:
    ------------------------
    
    "
    {template}
    "

    Guidelines you must follow are:
    -------------------------------
    {guidelines}
"""

src.from_prompt_gen_ans_main("./fdocs/theoretical_concepts_1.docx", system_message, user_message)
# Out:
# Content successfully written to ./fdocs/theoretical_concepts_1.docx

# %%
system_message = """
    You are an expert educator in physics and also a quality content generator for publishing a physics textbook of class 9. 
    Your goal is to create a very detailed "Theoretical Concept" part of a topic of a chapter for class 9 physics textbook (US).
    Your should keep in mind through the chapter that you should only generate age-appropriate and class-appropriate content strictly. It should not be beyond class 9 level.
"""

# Example usage:
file_path = "./fdocs/intro.docx"  # Replace with your DOCX file path
presponse = src.read_docx(file_path)
file_path = "./fdocs/objectives.docx"  # Replace with your DOCX file path
presponse += src.read_docx(file_path)


# file_path = "./fdocs/theoretical_concepts_1.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)
# file_path = "./fdocs/theoretical_concepts_2.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)
# file_path = "./fdocs/theoretical_concepts_3.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)

# file_path = "./fdocs/theoretical_concepts_4.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)

# file_path = "./fdocs/theoretical_concepts_5.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)

# file_path = "./fdocs/theoretical_concepts_6.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)
user_message = f"""
    You already gave me content for introduction and objectives as:

    {presponse}.

    --------------------------------------------------------



    --------------------------------------------------------
    Here, you should generate content only for the part,

    "
    Laws of Motion
    1. Real life examples
    2. Newton's First law very vey detailed elboration connecting to real-world examples, including complete theory and mathematical formulations derivations and explanation of each term detailedly (e.g. mass, inertia and differences between them). 
    3. Newton's second law very vey detailed elboration connecting to real-world examples, including complete theory and mathematical formulations derivations and explanation of each term detailedly (e.g. momentum, what is rate of change of momentum etc). 
    2. Newton's third law very vey detailed elboration connecting to real-world examples, including complete theory and mathematical formulations derivations and explanation of each term detailedly (e.g. action forces and reaction forces etc with real examples). 
    5. Some non-repetitive Solved step-by-step examples for each law after the theory.
    6. Do not include more headings. Include paragraphs like more story-telling type.
    "    
    --------------------------------------------------------
    Template you can follow:
    ------------------------
    
    "
    {template}
    "

    Guidelines you must follow are:
    -------------------------------
    {guidelines}
"""

src.from_prompt_gen_ans_main("./fdocs/theoretical_concepts_2.docx", system_message, user_message)
# Out:
# Content successfully written to ./fdocs/theoretical_concepts_2.docx

# %%
system_message = """
    You are an expert educator in physics and also a quality content generator for publishing a physics textbook of class 9. 
    Your goal is to create a very detailed "Theoretical Concept" part of a topic of a chapter for class 9 physics textbook (US).
    Your should keep in mind through the chapter that you should only generate age-appropriate and class-appropriate content strictly. It should not be beyond class 9 level.
"""

# Example usage:
file_path = "./fdocs/intro.docx"  # Replace with your DOCX file path
presponse = src.read_docx(file_path)
file_path = "./fdocs/objectives.docx"  # Replace with your DOCX file path
presponse += src.read_docx(file_path)


file_path = "./fdocs/theoretical_concepts_1.docx"  # Replace with your DOCX file path
presponse += src.read_docx(file_path)
file_path = "./fdocs/theoretical_concepts_2.docx"  # Replace with your DOCX file path
presponse += src.read_docx(file_path)
# file_path = "./fdocs/theoretical_concepts_3.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)

# file_path = "./fdocs/theoretical_concepts_4.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)

# file_path = "./fdocs/theoretical_concepts_5.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)

# file_path = "./fdocs/theoretical_concepts_6.docx"  # Replace with your DOCX file path
# presponse += src.read_docx(file_path)
user_message = f"""
    You already gave me content for introduction and objectives as:

    {presponse}.

    --------------------------------------------------------



    --------------------------------------------------------
    Here, you should generate content only for the part,

    "
    Conservation of momentum.
    1. Explain momentum first.
    2. Take real-life examples.
    3. Then explain what you mean by conservation.
    4. Then complete theoretical explanation of conservation of momentum along with detailed derivations, mathematical formulation explanatin of every term in details etc. 
    "    
    --------------------------------------------------------
    Template you can follow:
    ------------------------
    
    "
    {template}
    "

    Guidelines you must follow are:
    -------------------------------
    Expand this chapter, and explain all the terms and concepts in details before going to main topic and connect smoothly.
    {guidelines}
"""

src.from_prompt_gen_ans_main("./fdocs/theoretical_concepts_4.docx", system_message, user_message)
# Out:
# Content successfully written to ./fdocs/theoretical_concepts_4.docx
